# %%
import pandas as pd

# %%
data_1 = pd.read_csv("csv/omniart_v3_datadump.csv")

# %%
data_1.head()
# Out:
#                                      id             artwork_name  \
# 0  4ee8e28a-9df1-4af4-b9cc-c78a761c6b15                   70 amx
# 1  80fa7733-e6c6-4398-b20a-eff2c5bef278  monument of pope leo xi
# 2  17e45c05-c224-4e18-9885-03a1beae62ea     crucifixion (detail)
# 3  093cf203-734c-4828-bc94-391907932fee                    faith
# 4  fc0e311f-d85f-418c-b347-d5a9e0b81e8f                lamp post
#
#      artist_full_name artist_first_name artist_last_name creation_year  \
# 0             xynphix           xynphix          xynphix        2007.0
# 1  alessandro algardi        alessandro          algardi        1634.0
# 2   andrea da firenze         andrea da          firenze        1366.0
# 3     giuseppe angeli          giuseppe           angeli        1754.0
# 4        williamsnape      williamsnape     williamsnape        2010.0
#
#   century                                         source_url  \
# 0    21.0  https://xynphix.deviantart.com/art/70-AMX-5865...
# ...

# %%
pd.to_numeric(data_1.creation_year)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "unknown"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-21b4f12e3daf> in <module>
# ----> 1 pd.to_numeric(data_1.creation_year)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     148         try:
#     149             values = lib.maybe_convert_numeric(
# --> 150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#     152         except (ValueError, TypeError):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "unknown" at position 6286

# %%
list(set(data_1.school))
# Out:
# [nan,
#  'pp. 212. simpkin, marshall & co. london, 1888',
#  'montenegrin',
#  'bourges',
#  'london, warrington [printed]',
#  'new-york & philadelphia',
#  'marietta, o',
#  'bathoni',
#  'mejico',
#  'thame',
#  'selby [printed], london',
#  'st. petersburg, leipzig',
#  'london, holland [printed',
#  'pp. 43. fowler wright london, 1928',
#  'brazilian',
#  'sapi',
#  'inveraray',
#  'konigsberg pr',
#  'chichester',
#  'pp. 448. j. & r. maxwell london, [1888.]',
#  'esslingen, stuttgart [printed]',
#  'london,]',
#  'pp. vi. 471. richard bentley & son london, 1888',
#  'milano',
#  'printed for j. tonson',
#  'pp. 232. ward & downey london, [1888.]',
#  'london; belfast [printed]',
#  'delft',
#  'liverpool; published for the author, at the subscription library',
#  'avignon',
#  'st. helier',
#  'topeka, kansas',
#  'glasgow',
#  'waterbury',
#  'weida',
#  'chamberg',
#  'macmillan & co',
#  'dresden [printed] und leipzig',
#  'roche',
#  'tolosa',
#  '1877?]',
#  'paisley',
# ...

# %%
# Out:
# id                           1946273
# artwork_name                 1946273
# artist_full_name             1946273
# artist_first_name            1946273
# artist_last_name             1946273
# creation_year                1946273
# century                      1946273
# source_url                   1946273
# image_url                    1946273
# collection_origins           1946273
# artwork_type                 1946273
# school                       1946273
# original_id_in_collection    1946273
# created_at                   1946273
# last_modified                1946273
# omni_id                      1946273
# created_by_id                1946273
# general_type                 1946273
# geocoded                     1946273
# color_pallete                1946273
# dominant_color               1946273
# palette_count                1946273
# dtype: int64
